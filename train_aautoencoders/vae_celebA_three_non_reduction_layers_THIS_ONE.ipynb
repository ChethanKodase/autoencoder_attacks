# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn, optim
from torchvision import datasets, transforms

import zipfile

import shutil
import os
import pandas as pd

device = ("cuda" if torch.cuda.is_available() else "cpu") # Use GPU or CPU for training

# %%
'''with zipfile.ZipFile("celeba.zip","r") as zip_ref:
  zip_ref.extractall("data_faces/")'''
# Out:
# 'with zipfile.ZipFile("celeba.zip","r") as zip_ref:\n  zip_ref.extractall("data_faces/")'

# %%
root = 'data_faces/img_align_celeba'
img_list = os.listdir(root)
print(len(img_list))
# Out:
# 202599

# %%
df = pd.read_csv("list_attr_celeba.csv")
df = df[['image_id', 'Smiling']]

# %%
# to make directories

'''!rm -rf data
# !mkdir data && mkdir data/smile && mkdir data/no_smile'''
# Out:
# '!rm -rf data\n!mkdir data && mkdir data/smile && mkdir data/no_smile'

# %%
'''
s0 = 0
s1 = 0

num = 70000

for i, (_, i_row) in enumerate(df.iterrows()):
  if s0 < num:
    if i_row['Smiling'] == 1:
      s0 += 1
      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/smile/' + i_row['image_id'])
  
  if s1 < num:
    if i_row['Smiling'] == -1:
      s1 += 1
      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/no_smile/' + i_row['image_id'])
  
  if s0 == num and s1 == num:
    break'''
# Out:
# "\ns0 = 0\ns1 = 0\n\nnum = 70000\n\nfor i, (_, i_row) in enumerate(df.iterrows()):\n  if s0 < num:\n    if i_row['Smiling'] == 1:\n      s0 += 1\n      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/smile/' + i_row['image_id'])\n  \n  if s1 < num:\n    if i_row['Smiling'] == -1:\n      s1 += 1\n      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/no_smile/' + i_row['image_id'])\n  \n  if s0 == num and s1 == num:\n    break"

# %%
img_list = os.listdir('data_cel/smile/')
img_list.extend(os.listdir('data_cel/no_smile/'))

# %%
print("Images: ", len(img_list))
# Out:
# Images:  140000

# %%
transform = transforms.Compose([
          transforms.Resize((64, 64)),
          transforms.ToTensor()
          ])

batch_size = 64
celeba_data = datasets.ImageFolder('data_cel', transform=transform)

# %%
print(celeba_data.classes)
print(len(celeba_data))
# Out:
# ['no_smile', 'smile']
# 140000

# %%
train_set, test_set = torch.utils.data.random_split(celeba_data, [int(len(img_list) * 0.75), len(img_list) - int(len(img_list) * 0.75)])
train_data_size = len(train_set)
test_data_size = len(test_set)

# %%
trainLoader = torch.utils.data.DataLoader(train_set,batch_size=batch_size, shuffle=True)
testLoader  = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True)

# %%
print(train_data_size)
print(test_data_size)
# Out:
# 105000
# 35000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from vae import VAE, VAE_big

# %%
image_channels = 3

print('image_channels', image_channels)

#model = VAE(image_channels=image_channels).to(device)

model = VAE_big(image_channels=image_channels).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# image_channels 3

# %%
def loss_fn(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x, size_average=False)
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD, BCE, KLD

# %%
epochs = 200

# %%
train_loss = []

for epoch in range(epochs):
   
    total_train_loss = 0
    # training our model
    for idx, (image, label) in enumerate(trainLoader):
        images, label = image.to(device), label.to(device)

        recon_images, mu, logvar = model(images.to(device))
        loss, bce, kld = loss_fn(recon_images.to(device), images.to(device), mu.to(device), logvar.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


    print('loss', loss)
    print("Epoch : ", epoch)


torch.save(model.state_dict(), '/home/luser/autoencoder_attacks/saved_celebA/celebA_CNN_VAE_big_trainSize'+str(train_data_size)+'_epochs'+str(epochs)+'.torch')
# Out:
# /home/luser/anaconda3/envs/inn/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# loss tensor(253064.0625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  0
# loss tensor(250506.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  1
# loss tensor(249620.1406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  2
# loss tensor(242719.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  3
# loss tensor(247841.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  4
# loss tensor(240646.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  5
# loss tensor(245211., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  6
# loss tensor(238905.9375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  7
# loss tensor(245905.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  8
# loss tensor(250028.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  9
# loss tensor(242955.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  10
# loss tensor(244011.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  11
# loss tensor(240400.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  12
# loss tensor(249514.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  13
# loss tensor(248041.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  14
# loss tensor(235775.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  15
# loss tensor(227516.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  16
# loss tensor(238782.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  17
# loss tensor(246589.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  18
# loss tensor(239059.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  19
# loss tensor(247928.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  20
# loss tensor(233516.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  21
# loss tensor(232194.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  22
# loss tensor(243081.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  23
# loss tensor(254384.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  24
# loss tensor(239149.2344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  25
# loss tensor(238397.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  26
# loss tensor(244337.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  27
# loss tensor(245789.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  28
# loss tensor(230713.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  29
# loss tensor(241149.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  30
# loss tensor(247664.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  31
# loss tensor(237496.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  32
# loss tensor(247097.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  33
# loss tensor(232431.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  34
# loss tensor(238449.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  35
# loss tensor(238780.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  36
# loss tensor(242523.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  37
# loss tensor(232967.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  38
# loss tensor(237604.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  39
# loss tensor(220150.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  40
# loss tensor(232957.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  41
# loss tensor(234124.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  42
# loss tensor(235287.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  43
# loss tensor(248996.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  44
# loss tensor(241663.2969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  45
# loss tensor(237388.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  46
# loss tensor(236184.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  47
# loss tensor(233647.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  48
# loss tensor(235237.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  49
# loss tensor(241872.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  50
# loss tensor(245250.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  51
# loss tensor(224633.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  52
# loss tensor(238061.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  53
# loss tensor(234855.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  54
# loss tensor(241762.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  55
# loss tensor(239332.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  56
# loss tensor(242408.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  57
# loss tensor(234255.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  58
# loss tensor(242182.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  59
# loss tensor(251609.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  60
# loss tensor(232411.0469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  61
# loss tensor(242033.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  62
# loss tensor(238865.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  63
# loss tensor(236807.0469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  64
# loss tensor(229777.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  65
# loss tensor(233414.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  66
# loss tensor(229861.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  67
# loss tensor(224421.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  68
# loss tensor(239957.6094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  69
# loss tensor(248568.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  70
# loss tensor(236478.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  71
# loss tensor(238260.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  72
# loss tensor(245534.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  73
# loss tensor(243743.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  74
# loss tensor(228288.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  75
# loss tensor(240186.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  76
# loss tensor(246654.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  77
# loss tensor(231898.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  78
# loss tensor(241308.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  79
# loss tensor(239972.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  80
# loss tensor(245145.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  81
# loss tensor(232221.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  82
# loss tensor(242735.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  83
# loss tensor(242122.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  84
# loss tensor(235566.0469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  85
# loss tensor(242729.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  86
# loss tensor(233516.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  87
# loss tensor(243169.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  88
# loss tensor(244727.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  89
# loss tensor(248641.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  90
# loss tensor(236119.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  91
# loss tensor(236822.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  92
# loss tensor(254052.2969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  93
# loss tensor(241496.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  94
# loss tensor(235514.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  95
# loss tensor(243018.2344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  96
# loss tensor(244864.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  97
# loss tensor(253958.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  98
# loss tensor(241516.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  99
# loss tensor(234918.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  100
# loss tensor(240922.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  101
# loss tensor(247965.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  102
# loss tensor(244132.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  103
# loss tensor(247623.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  104
# loss tensor(248473.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  105
# loss tensor(235993.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  106
# loss tensor(251917.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  107
# loss tensor(232277.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  108
# loss tensor(248860.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  109
# loss tensor(236010.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  110
# loss tensor(231826.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  111
# loss tensor(242040., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  112
# loss tensor(235272.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  113
# loss tensor(242485.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  114
# loss tensor(231640.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  115
# loss tensor(236652.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  116
# loss tensor(236962.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  117
# loss tensor(243793.2969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  118
# loss tensor(239703.1719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  119
# loss tensor(229560.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  120
# loss tensor(228233.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  121
# loss tensor(241079.7031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  122
# loss tensor(235484.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  123
# loss tensor(231852.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  124
# loss tensor(230716., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  125
# loss tensor(230933.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  126
# loss tensor(240439.1406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  127
# loss tensor(247573.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  128
# loss tensor(231472.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  129
# loss tensor(222727.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  130
# loss tensor(242666.1719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  131
# loss tensor(245939.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  132
# loss tensor(247654., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  133
# loss tensor(245972.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  134
# loss tensor(237174.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  135
# loss tensor(229793.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  136
# loss tensor(228381.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  137
# loss tensor(247376.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  138
# loss tensor(229938.0625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  139
# loss tensor(243120.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  140
# loss tensor(242072.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  141
# loss tensor(237117.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  142
# loss tensor(243609.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  143
# loss tensor(236763.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  144
# loss tensor(238253.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  145
# loss tensor(239576.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  146
# loss tensor(239231.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  147
# loss tensor(247903.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  148
# loss tensor(237605.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  149
# loss tensor(238154.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  150
# loss tensor(244691.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  151
# loss tensor(233868.0469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  152
# loss tensor(244277.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  153
# loss tensor(247343., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  154
# loss tensor(237191.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  155
# loss tensor(240410.7031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  156
# loss tensor(227426.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  157
# loss tensor(233621.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  158
# loss tensor(230040.2969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  159
# loss tensor(234918.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  160
# loss tensor(239037.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  161
# loss tensor(226825.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  162
# loss tensor(246054.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  163
# loss tensor(236786.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  164
# loss tensor(246953.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  165
# loss tensor(244586.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  166
# loss tensor(240042.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  167
# loss tensor(241293.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  168
# loss tensor(236956.9062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  169
# loss tensor(239978.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  170

# %%
model = VAE_big(image_channels=image_channels).to(device)

# %%
model.load_state_dict(torch.load('/home/luser/autoencoder_attacks/saved_celebA/celebA_CNN_VAE_big_trainSize'+str(train_data_size)+'_epochs'+str(epochs)+'.torch'))

# Set the model to evaluation mode (if needed)
model.eval()
# Out:
# VAE_big(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#     (9): ReLU()
#     (10): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2))
#     (11): ReLU()
#     (12): Conv2d(256, 256, kernel_size=(4, 4), stride=(2, 2))
#     (13): ReLU()
#     (14): Flatten()
#   )
#   (fc1): Linear(in_features=1024, out_features=256, bias=True)
#   (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1024, bias=True)
#   (decoder): Sequential(
#     (0): UnFlatten()
#     (1): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2))
#     (2): ReLU()
#     (3): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2))
#     (4): ReLU()
#     (5): ConvTranspose2d(128, 64, kernel_size=(6, 6), stride=(2, 2))
#     (6): ReLU()
#     (7): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU()
#     (9): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (10): ReLU()
#     (11): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): ReLU()
#     (13): ConvTranspose2d(64, 3, kernel_size=(6, 6), stride=(2, 2))
#     (14): Sigmoid()
#   )
# )

# %%
for idx, (image, label) in enumerate(trainLoader):
    images, label = image.to(device), label.to(device)
    break

# %%
recon_images, mu, logvar = model(images.to(device))

# %%
recon_images.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
selected_ind = 7

# %%
plt.imshow(images[selected_ind].permute(1, 2, 0).cpu().detach().numpy(), cmap=plt.cm.gray_r, interpolation='nearest')

# %%
plt.imshow(recon_images[selected_ind].permute(1, 2, 0).cpu().detach().numpy(), cmap=plt.cm.gray_r, interpolation='nearest')
