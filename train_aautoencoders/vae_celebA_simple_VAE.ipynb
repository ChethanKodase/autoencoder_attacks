# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn, optim
from torchvision import datasets, transforms

import zipfile

import shutil
import os
import pandas as pd

device = ("cuda" if torch.cuda.is_available() else "cpu") # Use GPU or CPU for training

# %%
'''with zipfile.ZipFile("celeba.zip","r") as zip_ref:
  zip_ref.extractall("data_faces/")'''
# Out:
# 'with zipfile.ZipFile("celeba.zip","r") as zip_ref:\n  zip_ref.extractall("data_faces/")'

# %%
root = 'data_faces/img_align_celeba'
img_list = os.listdir(root)
print(len(img_list))
# Out:
# 202599

# %%
df = pd.read_csv("list_attr_celeba.csv")
df = df[['image_id', 'Smiling']]

# %%
# to make directories

'''!rm -rf data
# !mkdir data_cel && mkdir data_cel/smile && mkdir data_cel/no_smile'''
# Out:
# '!rm -rf data\n!mkdir data_cel && mkdir data_cel/smile && mkdir data_cel/no_smile'

# %%
'''
s0 = 0
s1 = 0

num = 70000

for i, (_, i_row) in enumerate(df.iterrows()):
  if s0 < num:
    if i_row['Smiling'] == 1:
      s0 += 1
      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/smile/' + i_row['image_id'])
  
  if s1 < num:
    if i_row['Smiling'] == -1:
      s1 += 1
      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/no_smile/' + i_row['image_id'])
  
  if s0 == num and s1 == num:
    break'''
# Out:
# "\ns0 = 0\ns1 = 0\n\nnum = 70000\n\nfor i, (_, i_row) in enumerate(df.iterrows()):\n  if s0 < num:\n    if i_row['Smiling'] == 1:\n      s0 += 1\n      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/smile/' + i_row['image_id'])\n  \n  if s1 < num:\n    if i_row['Smiling'] == -1:\n      s1 += 1\n      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/no_smile/' + i_row['image_id'])\n  \n  if s0 == num and s1 == num:\n    break"

# %%
img_list = os.listdir('data_cel/smile/')
img_list.extend(os.listdir('data_cel/no_smile/'))

# %%
print("Images: ", len(img_list))
# Out:
# Images:  140000

# %%
transform = transforms.Compose([
          transforms.Resize((64, 64)),
          transforms.ToTensor()
          ])

batch_size = 64
celeba_data = datasets.ImageFolder('data_cel', transform=transform)

# %%
print(celeba_data.classes)
print(len(celeba_data))
# Out:
# ['no_smile', 'smile']
# 140000

# %%
train_set, test_set = torch.utils.data.random_split(celeba_data, [int(len(img_list) * 0.75), len(img_list) - int(len(img_list) * 0.75)])
train_data_size = len(train_set)
test_data_size = len(test_set)

# %%
trainLoader = torch.utils.data.DataLoader(train_set,batch_size=batch_size, shuffle=True)
testLoader  = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True)

# %%
print(train_data_size)
print(test_data_size)
# Out:
# 105000
# 35000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from vae import VAE, VAE_big, VAE_big_consti

# %%
image_channels = 3

print('image_channels', image_channels)

model = VAE(image_channels=image_channels).to(device)
#model = VAE_big(image_channels=image_channels).to(device)

#model = VAE_big_consti(image_channels=image_channels).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# image_channels 3

# %%
def loss_fn(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x, size_average=False)
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD, BCE, KLD

# %%
epochs = 200

# %%
train_loss = []

for epoch in range(epochs):
   
    total_train_loss = 0
    # training our model
    for idx, (image, label) in enumerate(trainLoader):
        images, label = image.to(device), label.to(device)
        embedding = model.encoder(images.to(device))

        recon_images, mu, logvar = model(images.to(device))
        loss, bce, kld = loss_fn(recon_images.to(device), images.to(device), mu.to(device), logvar.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


    print('loss', loss)
    print("Epoch : ", epoch)


torch.save(model.state_dict(), '/home/luser/autoencoder_attacks/saved_celebA/celebA_simple_CNN_VAE_trainSize'+str(train_data_size)+'_epochs'+str(epochs)+'.torch')
# Out:
# /home/luser/anaconda3/envs/inn/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# loss tensor(263349.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  0
# loss tensor(256720.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  1
# loss tensor(259932.0156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  2
# loss tensor(238606., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  3
# loss tensor(236611.7031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  4
# loss tensor(243785.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  5
# loss tensor(237550.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  6
# loss tensor(239170.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  7
# loss tensor(246149.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  8
# loss tensor(246939.6094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  9
# loss tensor(243763.1406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  10
# loss tensor(240864.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  11
# loss tensor(236660.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  12
# loss tensor(233497.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  13
# loss tensor(237151.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  14
# loss tensor(239033.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  15
# loss tensor(247499.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  16
# loss tensor(250335.2188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  17
# loss tensor(243496.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  18
# loss tensor(240350.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  19
# loss tensor(243565.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  20
# loss tensor(247233., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  21
# loss tensor(237303.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  22
# loss tensor(242405.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  23
# loss tensor(228148.7656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  24
# loss tensor(242140.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  25
# loss tensor(248436.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  26
# loss tensor(242449.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  27
# loss tensor(233294.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  28
# loss tensor(236423.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  29
# loss tensor(239075.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  30
# loss tensor(240917.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  31
# loss tensor(241042.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  32
# loss tensor(245883., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  33
# loss tensor(254072.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  34
# loss tensor(251019.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  35
# loss tensor(231347.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  36
# loss tensor(241421.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  37
# loss tensor(242573.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  38
# loss tensor(244696.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  39
# loss tensor(231783.2344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  40
# loss tensor(256930.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  41
# loss tensor(243902.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  42
# loss tensor(236558.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  43
# loss tensor(238368.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  44
# loss tensor(233420., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  45
# loss tensor(235634.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  46
# loss tensor(236105.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  47
# loss tensor(247669.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  48
# loss tensor(237483.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  49
# loss tensor(235626.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  50
# loss tensor(233822.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  51
# loss tensor(246242.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  52
# loss tensor(238790.9375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  53
# loss tensor(240956.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  54
# loss tensor(233215.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  55
# loss tensor(234933.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  56
# loss tensor(230139.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  57
# loss tensor(232726.0625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  58
# loss tensor(237965.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  59
# loss tensor(237968.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  60
# loss tensor(248495.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  61
# loss tensor(242712.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  62
# loss tensor(252589.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  63
# loss tensor(240792.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  64
# loss tensor(230031.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  65
# loss tensor(241466.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  66
# loss tensor(239993.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  67
# loss tensor(242668.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  68
# loss tensor(244891.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  69
# loss tensor(237518.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  70
# loss tensor(235296.9375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  71
# loss tensor(244040.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  72
# loss tensor(234566.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  73
# loss tensor(247658.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  74
# loss tensor(238171.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  75
# loss tensor(252923.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  76
# loss tensor(226029.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  77
# loss tensor(234968.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  78
# loss tensor(245939.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  79
# loss tensor(252238., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  80
# loss tensor(234462.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  81
# loss tensor(241510.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  82
# loss tensor(233821.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  83
# loss tensor(241506.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  84
# loss tensor(227168.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  85
# loss tensor(240889.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  86
# loss tensor(248351.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  87
# loss tensor(240184.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  88
# loss tensor(230491.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  89
# loss tensor(250793.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  90
# loss tensor(237390.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  91
# loss tensor(234485.9375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  92
# loss tensor(237498.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  93
# loss tensor(241622.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  94
# loss tensor(234507.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  95
# loss tensor(246837.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  96
# loss tensor(244215.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  97
# loss tensor(225785.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  98
# loss tensor(234315.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  99
# loss tensor(231503., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  100
# loss tensor(254007.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  101
# loss tensor(246554.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  102
# loss tensor(250640.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  103
# loss tensor(249730.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  104
# loss tensor(239365.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  105
# loss tensor(240325.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  106
# loss tensor(240421.2344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  107
# loss tensor(242080.7656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  108
# loss tensor(241071.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  109
# loss tensor(226329.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  110
# loss tensor(245562.2969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  111
# loss tensor(243712.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  112
# loss tensor(240064.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  113
# loss tensor(249172.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  114
# loss tensor(245067.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  115
# loss tensor(241852.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  116
# loss tensor(231403.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  117
# loss tensor(221983.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  118
# loss tensor(238371.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  119
# loss tensor(238030.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  120
# loss tensor(234182.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  121
# loss tensor(240625.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  122
# loss tensor(250763.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  123
# loss tensor(237972.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  124
# loss tensor(240534.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  125
# loss tensor(240441.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  126
# loss tensor(241605.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  127
# loss tensor(238224.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  128
# loss tensor(226668.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  129
# loss tensor(235485.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  130
# loss tensor(241968.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  131
# loss tensor(246485.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  132
# loss tensor(243464.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  133
# loss tensor(240026.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  134
# loss tensor(244573.9062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  135
# loss tensor(237536.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  136
# loss tensor(240025.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  137
# loss tensor(231297.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  138
# loss tensor(233205.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  139
# loss tensor(240819.2344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  140
# loss tensor(250026.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  141
# loss tensor(240128.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  142
# loss tensor(236790., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  143
# loss tensor(240542.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  144
# loss tensor(238994.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  145
# loss tensor(232508.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  146
# loss tensor(240506.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  147
# loss tensor(243554.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  148
# loss tensor(245749.0156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  149
# loss tensor(254663.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  150
# loss tensor(240045.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  151
# loss tensor(235910.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  152
# loss tensor(239417.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  153
# loss tensor(240432.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  154
# loss tensor(242098.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  155
# loss tensor(247034.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  156
# loss tensor(240939.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  157
# loss tensor(236400.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  158
# loss tensor(248031.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  159
# loss tensor(238101.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  160
# loss tensor(251566.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  161
# loss tensor(237158.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  162
# loss tensor(248533.2969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  163
# loss tensor(247698.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  164
# loss tensor(241845.1406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  165
# loss tensor(240986.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  166
# loss tensor(237698.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  167
# loss tensor(237203.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  168
# loss tensor(239713.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  169
# loss tensor(242351.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  170
# loss tensor(232198.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  171
# loss tensor(239194.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  172
# loss tensor(240703.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  173
# loss tensor(237869.0156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  174
# loss tensor(243214.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  175
# loss tensor(238801.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  176
# loss tensor(235790.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  177
# loss tensor(250951.1719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  178
# loss tensor(234026.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  179
# loss tensor(235988.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  180
# loss tensor(230024.0469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  181
# loss tensor(240387.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  182
# loss tensor(239903.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  183
# loss tensor(237228., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  184
# loss tensor(245646.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  185
# loss tensor(233912.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  186
# loss tensor(238132.2188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  187
# loss tensor(234762.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  188
# loss tensor(229860.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  189
# loss tensor(243092.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  190
# loss tensor(237211.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  191
# loss tensor(231417.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  192
# loss tensor(243205.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  193
# loss tensor(227024.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  194
# loss tensor(240059.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  195
# loss tensor(246475.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  196
# loss tensor(233361.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  197
# loss tensor(246403.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  198
# loss tensor(243246.9531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  199

# %%
model = VAE(image_channels=image_channels).to(device)

# %%
model.load_state_dict(torch.load('/home/luser/autoencoder_attacks/saved_celebA/celebA_simple_CNN_VAE_trainSize'+str(train_data_size)+'_epochs'+str(epochs)+'.torch'))

# Set the model to evaluation mode (if needed)
model.eval()
# Out:
# VAE(
#   (encoder): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2))
#     (5): ReLU()
#     (6): Conv2d(256, 256, kernel_size=(4, 4), stride=(2, 2))
#     (7): ReLU()
#     (8): Flatten()
#   )
#   (fc1): Linear(in_features=1024, out_features=256, bias=True)
#   (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1024, bias=True)
#   (decoder): Sequential(
#     (0): UnFlatten()
#     (1): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2))
#     (2): ReLU()
#     (3): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2))
#     (4): ReLU()
#     (5): ConvTranspose2d(128, 64, kernel_size=(6, 6), stride=(2, 2))
#     (6): ReLU()
#     (7): ConvTranspose2d(64, 3, kernel_size=(6, 6), stride=(2, 2))
#     (8): Sigmoid()
#   )
# )

# %%
for idx, (image, label) in enumerate(trainLoader):
    images, label = image.to(device), label.to(device)
    break

# %%
recon_images, mu, logvar = model(images.to(device))

# %%
recon_images.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
selected_ind = 7

# %%
plt.imshow(images[selected_ind].permute(1, 2, 0).cpu().detach().numpy(), cmap=plt.cm.gray_r, interpolation='nearest')

# %%
plt.imshow(recon_images[selected_ind].permute(1, 2, 0).cpu().detach().numpy(), cmap=plt.cm.gray_r, interpolation='nearest')
