# %%
import matplotlib.pyplot as plt
import numpy as np

import torch
from torch import nn, optim
from torchvision import datasets, transforms

import zipfile

import shutil
import os
import pandas as pd

device = ("cuda" if torch.cuda.is_available() else "cpu") # Use GPU or CPU for training

# %%
'''with zipfile.ZipFile("celeba.zip","r") as zip_ref:
  zip_ref.extractall("data_faces/")'''
# Out:
# 'with zipfile.ZipFile("celeba.zip","r") as zip_ref:\n  zip_ref.extractall("data_faces/")'

# %%
root = 'data_faces/img_align_celeba'
img_list = os.listdir(root)
print(len(img_list))
# Out:
# 202599

# %%
df = pd.read_csv("list_attr_celeba.csv")
#df = df[['image_id', 'Smiling']]

# %%
df
#get all the row titles
df.index
# get all the column titles
df.columns
# Out:
# Index(['image_id', '5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive',
#        'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose',
#        'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows',
#        'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair',
#        'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open',
#        'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin',
#        'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns',
#        'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings',
#        'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace',
#        'Wearing_Necktie', 'Young'],
#       dtype='object')

# %%
# to make directories

'''!rm -rf data
# !mkdir data && mkdir data/smile && mkdir data/no_smile'''
# Out:
# '!rm -rf data\n!mkdir data && mkdir data/smile && mkdir data/no_smile'

# %%
'''
s0 = 0
s1 = 0

num = 70000

for i, (_, i_row) in enumerate(df.iterrows()):
  if s0 < num:
    if i_row['Smiling'] == 1:
      s0 += 1
      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/smile/' + i_row['image_id'])
  
  if s1 < num:
    if i_row['Smiling'] == -1:
      s1 += 1
      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/no_smile/' + i_row['image_id'])
  
  if s0 == num and s1 == num:
    break'''
# Out:
# "\ns0 = 0\ns1 = 0\n\nnum = 70000\n\nfor i, (_, i_row) in enumerate(df.iterrows()):\n  if s0 < num:\n    if i_row['Smiling'] == 1:\n      s0 += 1\n      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/smile/' + i_row['image_id'])\n  \n  if s1 < num:\n    if i_row['Smiling'] == -1:\n      s1 += 1\n      shutil.copyfile('data_faces/img_align_celeba/' + i_row['image_id'], 'data_cel/no_smile/' + i_row['image_id'])\n  \n  if s0 == num and s1 == num:\n    break"

# %%
img_list = os.listdir('data_cel/smile/')
img_list.extend(os.listdir('data_cel/no_smile/'))

# %%
print("Images: ", len(img_list))
# Out:
# Images:  140000

# %%
transform = transforms.Compose([
          transforms.Resize((64, 64)),
          transforms.ToTensor()
          ])

batch_size = 64
celeba_data = datasets.ImageFolder('data_cel', transform=transform)

# %%
print(celeba_data.classes)
print(len(celeba_data))
# Out:
# ['no_smile', 'smile']
# 140000

# %%
train_set, test_set = torch.utils.data.random_split(celeba_data, [int(len(img_list) * 0.75), len(img_list) - int(len(img_list) * 0.75)])
train_data_size = len(train_set)
test_data_size = len(test_set)

# %%
trainLoader = torch.utils.data.DataLoader(train_set,batch_size=batch_size, shuffle=True)
testLoader  = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle=True)

# %%
print(train_data_size)
print(test_data_size)
# Out:
# 105000
# 35000

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from vae import VAE, VAE_big, VAE_big_layered

# %%
image_channels = 3

print('image_channels', image_channels)

#model = VAE(image_channels=image_channels).to(device)

model = VAE_big_layered(image_channels=image_channels).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# image_channels 3

# %%
def loss_fn(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x, size_average=False)
    KLD = -0.5 * torch.mean(1 + logvar - mu.pow(2) - logvar.exp())

    return BCE + KLD, BCE, KLD

# %%
epochs = 200

# %%
train_loss = []

for epoch in range(epochs):
   
    total_train_loss = 0
    # training our model
    for idx, (image, label) in enumerate(trainLoader):
        images, label = image.to(device), label.to(device)

        recon_images, mu, logvar = model(images.to(device))
        loss, bce, kld = loss_fn(recon_images.to(device), images.to(device), mu.to(device), logvar.to(device))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()


    print('loss', loss)
    print("Epoch : ", epoch)


torch.save(model.state_dict(), '/home/luser/autoencoder_attacks/saved_celebA/celebA_CNN_VAE_big_layered_trainSize'+str(train_data_size)+'_epochs'+str(epochs)+'.torch')
# Out:
# /home/luser/anaconda3/envs/inn/lib/python3.9/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# loss tensor(259125.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  0
# loss tensor(250966.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  1
# loss tensor(252196.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  2
# loss tensor(245273.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  3
# loss tensor(243416.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  4
# loss tensor(254816.4062, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  5
# loss tensor(250132.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  6
# loss tensor(248107.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  7
# loss tensor(252854.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  8
# loss tensor(244438.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  9
# loss tensor(229769.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  10
# loss tensor(240130.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  11
# loss tensor(234606.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  12
# loss tensor(245024.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  13
# loss tensor(251648.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  14
# loss tensor(243439.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  15
# loss tensor(248256.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  16
# loss tensor(237217.0625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  17
# loss tensor(250706.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  18
# loss tensor(237790.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  19
# loss tensor(238310.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  20
# loss tensor(232225.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  21
# loss tensor(245878.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  22
# loss tensor(250246.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  23
# loss tensor(232732.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  24
# loss tensor(242349.0156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  25
# loss tensor(237259.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  26
# loss tensor(246106.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  27
# loss tensor(240717.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  28
# loss tensor(236962.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  29
# loss tensor(239759.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  30
# loss tensor(238884.9375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  31
# loss tensor(238570.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  32
# loss tensor(233030.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  33
# loss tensor(235034.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  34
# loss tensor(243300.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  35
# loss tensor(240056.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  36
# loss tensor(240935.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  37
# loss tensor(242091.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  38
# loss tensor(239825.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  39
# loss tensor(247714.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  40
# loss tensor(239262.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  41
# loss tensor(242285.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  42
# loss tensor(238325.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  43
# loss tensor(256034.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  44
# loss tensor(246876.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  45
# loss tensor(242192.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  46
# loss tensor(244737.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  47
# loss tensor(232536.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  48
# loss tensor(248796.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  49
# loss tensor(236153.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  50
# loss tensor(242565.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  51
# loss tensor(244476.1719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  52
# loss tensor(230671.2188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  53
# loss tensor(240583.6250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  54
# loss tensor(230498.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  55
# loss tensor(242775.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  56
# loss tensor(245596.7031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  57
# loss tensor(242072.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  58
# loss tensor(238482.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  59
# loss tensor(229223.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  60
# loss tensor(243177., device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  61
# loss tensor(239355.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  62
# loss tensor(233718.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  63
# loss tensor(250609.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  64
# loss tensor(226086.1250, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  65
# loss tensor(240684.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  66
# loss tensor(239425.6875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  67
# loss tensor(235135.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  68
# loss tensor(249658.1719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  69
# loss tensor(235853.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  70
# loss tensor(247222.1406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  71
# loss tensor(229191.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  72
# loss tensor(247907.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  73
# loss tensor(239506.7656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  74
# loss tensor(234683.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  75
# loss tensor(242822.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  76
# loss tensor(245651.4844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  77
# loss tensor(239764.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  78
# loss tensor(236428.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  79
# loss tensor(226489.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  80
# loss tensor(249540.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  81
# loss tensor(235579.8750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  82
# loss tensor(243201.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  83
# loss tensor(240352.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  84
# loss tensor(239274.2188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  85
# loss tensor(235795.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  86
# loss tensor(236776.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  87
# loss tensor(238081.7188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  88
# loss tensor(239709.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  89
# loss tensor(233966.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  90
# loss tensor(236035.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  91
# loss tensor(239532.0469, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  92
# loss tensor(230366.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  93
# loss tensor(239309.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  94
# loss tensor(233243.1406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  95
# loss tensor(242602.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  96
# loss tensor(237729.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  97
# loss tensor(228657.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  98
# loss tensor(241953.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  99
# loss tensor(228840.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  100
# loss tensor(234735.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  101
# loss tensor(227124.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  102
# loss tensor(242091.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  103
# loss tensor(242034.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  104
# loss tensor(240690.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  105
# loss tensor(242585.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  106
# loss tensor(242675.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  107
# loss tensor(234629.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  108
# loss tensor(247409.2656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  109
# loss tensor(240450.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  110
# loss tensor(242235.4688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  111
# loss tensor(225770.2344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  112
# loss tensor(245887.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  113
# loss tensor(250073.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  114
# loss tensor(233733.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  115
# loss tensor(241969.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  116
# loss tensor(248475.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  117
# loss tensor(236170.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  118
# loss tensor(240057.8594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  119
# loss tensor(232320.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  120
# loss tensor(251132.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  121
# loss tensor(236460.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  122
# loss tensor(249474.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  123
# loss tensor(248757.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  124
# loss tensor(241824.3750, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  125
# loss tensor(245102.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  126
# loss tensor(233475.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  127
# loss tensor(235274.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  128
# loss tensor(237950.0938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  129
# loss tensor(242459.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  130
# loss tensor(235697.3438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  131
# loss tensor(235043.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  132
# loss tensor(243453.2812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  133
# loss tensor(246988.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  134
# loss tensor(237677.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  135
# loss tensor(245327.9688, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  136
# loss tensor(242817.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  137
# loss tensor(239398.6094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  138
# loss tensor(239403.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  139
# loss tensor(236305.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  140
# loss tensor(241609.9375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  141
# loss tensor(246887.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  142
# loss tensor(246808.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  143
# loss tensor(234081.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  144
# loss tensor(228498.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  145
# loss tensor(245032.1875, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  146
# loss tensor(242181.6406, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  147
# loss tensor(235951.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  148
# loss tensor(232829.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  149
# loss tensor(242376.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  150
# loss tensor(240513.6094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  151
# loss tensor(223435.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  152
# loss tensor(226797.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  153
# loss tensor(230731.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  154
# loss tensor(246681.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  155
# loss tensor(246850.4375, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  156
# loss tensor(241693.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  157
# loss tensor(247051.0625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  158
# loss tensor(250968.6562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  159
# loss tensor(235803.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  160
# loss tensor(240544.8906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  161
# loss tensor(243687.9219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  162
# loss tensor(235946.7031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  163
# loss tensor(234803.7656, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  164
# loss tensor(232113.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  165
# loss tensor(247584.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  166
# loss tensor(245090.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  167
# loss tensor(238819.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  168
# loss tensor(250475.3281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  169
# loss tensor(234359.5156, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  170
# loss tensor(237172.6094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  171
# loss tensor(238318.7500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  172
# loss tensor(233042.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  173
# loss tensor(243202.4531, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  174
# loss tensor(241010.5625, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  175
# loss tensor(241354.2188, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  176
# loss tensor(239073.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  177
# loss tensor(238238.5938, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  178
# loss tensor(239254.8125, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  179
# loss tensor(242062.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  180
# loss tensor(232948.0781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  181
# loss tensor(223723.7969, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  182
# loss tensor(241263.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  183
# loss tensor(230700.0312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  184
# loss tensor(237495.5000, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  185
# loss tensor(239439.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  186
# loss tensor(234283.2031, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  187
# loss tensor(241645.8281, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  188
# loss tensor(240769.7812, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  189
# loss tensor(228234.7344, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  190
# loss tensor(234148.1562, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  191
# loss tensor(237618.2500, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  192
# loss tensor(239906.1094, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  193
# loss tensor(224998.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  194
# loss tensor(241628.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  195
# loss tensor(246221.4219, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  196
# loss tensor(243524.3906, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  197
# loss tensor(244738.6719, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  198
# loss tensor(235910.5312, device='cuda:0', grad_fn=<AddBackward0>)
# Epoch :  199

# %%
model = VAE_big_layered(image_channels=image_channels).to(device)

# %%
model.load_state_dict(torch.load('/home/luser/autoencoder_attacks/saved_celebA/celebA_CNN_VAE_big_layered_trainSize'+str(train_data_size)+'_epochs'+str(epochs)+'.torch'))

# Set the model to evaluation mode (if needed)
model.eval()
# Out:
# VAE_big_layered(
#   (encoder_6): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#   )
#   (encoder_5): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (encoder_4): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (encoder_3): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (encoder_2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#   )
#   (encoder_1): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#   )
#   (encoder_0): Sequential(
#     (0): Conv2d(256, 256, kernel_size=(4, 4), stride=(2, 2))
#     (1): ReLU()
#     (2): Flatten()
#   )
#   (fc1): Linear(in_features=1024, out_features=256, bias=True)
#   (fc2): Linear(in_features=1024, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=1024, bias=True)
#   (decoder_0): Sequential(
#     (0): UnFlatten()
#     (1): ConvTranspose2d(1024, 256, kernel_size=(5, 5), stride=(2, 2))
#     (2): ReLU()
#   )
#   (decoder_1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(5, 5), stride=(2, 2))
#     (1): ReLU()
#   )
#   (decoder_2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(6, 6), stride=(2, 2))
#     (1): ReLU()
#   )
#   (decoder_3): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (decoder_4): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (decoder_5): Sequential(
#     (0): ConvTranspose2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (decoder_6): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(6, 6), stride=(2, 2))
#     (1): Sigmoid()
#   )
# )

# %%
for idx, (image, label) in enumerate(trainLoader):
    images, label = image.to(device), label.to(device)
    break

# %%
recon_images, mu, logvar = model(images.to(device))

# %%
recon_images.shape
# Out:
# torch.Size([64, 3, 64, 64])

# %%
selected_ind = 7

# %%
plt.imshow(images[selected_ind].permute(1, 2, 0).cpu().detach().numpy(), cmap=plt.cm.gray_r, interpolation='nearest')

# %%
plt.imshow(recon_images[selected_ind].permute(1, 2, 0).cpu().detach().numpy(), cmap=plt.cm.gray_r, interpolation='nearest')
